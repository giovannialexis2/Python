# %%
### Variables ###
my string variable = "My string variable"
print(my_string__variable)
my_int _variable = 5
print(my_ int_variable)

my_int_to_str_variable = str(my_ int_variable)
print (my_int_to_ str_variable)
print (type(my_int_to_str_variable))
my_bool_variable = Falce
# Out:
#   File "<ipython-input-6-eef0cbf10268>", line 2
#     my string variable = "My string variable"
#        ^
# SyntaxError: invalid syntax
